# %% [markdown]
# <a href="https://colab.research.google.com/github/Naveenkondisetty/FMML-LAB_22B21A4261/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-13 16:18:09--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  86.9MB/s    in 0.8s
#
# 2024-05-13 16:18:10 (86.9 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 25898  1512.03424v1  Object detection is a fundamental task in many...    cs
# 10120  1707.02515v1  For safe and efficient planning and control in...    cs
# 13116  1606.03956v1  In this work, we consider compressed sensing r...    cs
# 1162    1408.2938v1  The recent progress in sparse coding and deep ...    cs
# 2533   1511.06891v2  This paper addresses the problem of active lea...  stat
# ...             ...                                                ...   ...
# 5851    1206.6457v1  This paper analyzes the problem of Gaussian pr...    cs
# 21934  1612.00081v2  Variational inference provides a powerful tool...  stat
# 104    1504.01483v1  Deep Neural Network (DNN) acoustic models have...    cs
# 11241  1506.02557v2  We investigate a local reparameterizaton techn...  stat
# 31604  1803.07441v1  The local descriptors have gained wide range o...    cs
#
#                                                    title  year  \
# 25898  Evaluation of Object Detection Proposals Under...  2015
# 10120  A Fast Integrated Planning and Control Framewo...  2017
# 13116  Inferring Sparsity: Compressed Sensing using G...  2016
# 1162   Learning Multi-Scale Representations for Mater...  2014
# 2533   Near-Optimal Active Learning of Multi-Output G...  2015
# ...                                                  ...   ...
# 5851   Exponential Regret Bounds for Gaussian Process...  2012
# 21934         Two Methods For Wild Variational Inference  2016
# 104           Transferring Knowledge from a RNN to a DNN  2015
# 11241  Variational Dropout and the Local Reparameteri...  2015
# 31604  LDOP: Local Directional Order Pattern for Robu...  2018
#
#                                                 keywords
# 25898  [detection, fundamental, applications, therefo...
# 10120  [efficient, autonomous, desirable, guaranteed,...
# 13116  [compressed, reconstruction, measurements, str...
# 1162   [unsupervised, competitor, descriptors, predom...
# 2533   [addresses, representing, coexisting, correlat...
# ...                                                  ...
# 5851   [deterministic, observations, algorithm, algor...
# 21934  [variational, inference, approximate, probabil...
# 104    [automatic, recognition, recurrent, outperform...
# 11241  [investigate, reparameterizaton, technique, st...
# 31604  [descriptors, attention, discriminative, abili...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 25898    [detection, fundamental, applications, therefo...
# 10120    [efficient, autonomous, desirable, guaranteed,...
# 13116    [compressed, reconstruction, measurements, str...
# 1162     [unsupervised, competitor, descriptors, predom...
# 2533     [addresses, representing, coexisting, correlat...
#                                ...
# 9653     [distributions, binarized, boltzmann, accordin...
# 11352    [introduce, principal, differences, analyzing,...
# 6361     [ensembles, prediction, interpretability, inte...
# 9633     [rendering, algorithms, emphasize, aesthetic, ...
# 6224     [variational, autoencoder, developed, associat...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8710 words.
# Out of those 4590 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="83010712-a82e-476b-90e3-00580ebbba62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83010712-a82e-476b-90e3-00580ebbba62")) {                    Plotly.newPlot(                        "83010712-a82e-476b-90e3-00580ebbba62",                        [{"x":["experiments","outperformance","importance","selective","evaluating","therefore","capabilities","detection","evaluation","proposals","applications","introduced","condition","environmental","variations","illumination","fundamental","acknowledged","combination","demonstrate","guaranteed","effectiveness","feasibility","computational","complexity","framework","imitation","aggregation","established","hierarchical","scenarios","reference","unacceptable","sufficient","predictive","approaches","complicated","efficient","integrated","generated","demonstrated","execution","representative","controller","optimization","autonomous","performance","continuously","efficiency","desirable","implementation","structure","generally","compressed","unsupervised","reconstruction","measurements","restricted","integrate","effective","statistical","correlation","distribution","generative","approximate","inference","inferring","boltzmann","structured","generalized","predominantly","procedure","investigate","information","representations","strategies","resulting","competitor","recognition","benchmarks","classification","outperform","descriptors","incorporate","addresses","selecting","informative","polynomial","representing","phenomena","posterior","observations","locations","candidate","outperforms","guarantees","processes","phenomenon","criterion","correlated","submodularity","empirical","optimized","minimizing","approximation","uncertainty","algorithms","algorithm","unfortunately","alternative","recurrent","extraction","categories","submission","identifying","treatments","resources","initialized","predefined","challenge","embeddings","challenges","automated","experimental","processing","bidirectional","handcrafted","classifying","essential","streamlined","decomposition","manipulating","probabilistically","constraints","expressive","heuristics","geometrical","collision","configurations","languages","classical","geometric","compilation","combinatorial","functions","presented","components","independent","deterministic","interactively","underlying","parameter","intriguing","clustered","generalizes","community","theoretical","contribution","theoretic","represents","connection","relationships","interesting","probability","clustering","hellinger","logarithmically","knowledge","arbitrary","independently","similarity","drastically","significantly","otherwise","attributes","divergence","stochastic","interactive","limitation","discriminate","highlighting","statistics","empirically","construct","neuroscience","normalization","interpolate","successes","important","perceptually","parametrized","different","identical","discriminable","peripheral","dimensional","coefficients","critically","observers","physically"],"y":[629,1,95,16,53,138,48,331,255,26,437,143,57,24,77,37,89,3,143,520,31,188,25,279,270,527,7,27,55,111,97,53,3,58,66,419,26,420,62,163,117,28,38,22,334,57,890,12,167,51,114,347,78,23,159,105,48,60,55,253,186,72,210,109,117,210,33,22,102,77,3,142,161,713,244,77,160,3,380,95,531,79,64,78,60,52,34,66,87,20,40,79,48,48,276,65,96,29,48,26,1,140,59,41,119,81,591,801,29,85,133,137,85,8,61,2,74,4,11,133,74,127,109,400,291,18,11,36,80,1,68,12,4,141,32,40,14,5,20,104,104,72,6,33,223,203,107,136,47,10,121,115,7,13,31,66,156,80,38,62,39,74,70,152,149,1,2,344,79,44,148,23,268,21,66,25,120,43,28,13,12,59,69,88,17,34,7,11,370,8,8,780,21,2,2,182,43,11,5,12],"type":"bar"},{"x":["experiments","outperformance","impor ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4590,), (4590, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8041666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Visualizing</span> <span style=''>Natural</span> <span style=''>Language</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777778);'>Descriptions</span> <span style=''>A</span> <span style=''>Survey</span> <br/><br/><span style=''>A</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.41463414634146334);'>interface</span> <span style=''>exploits</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>conceptual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simplicity</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>naturalness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>language</span> <span style=''>to</span> <span style=''>create</span> <span style=''>a</span> <span style=''>high</span> <span style=''>level</span> <span style=''>user</span> <span style=''>friendly</span> <span style='background-color:rgba(0, 255, 0, 0.45945945945945943);'>communication</span> <span style=''>channel</span> <span style=''>between</span> <span style=''>humans</span> <span style=''>and</span> <span style=''>machines</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3908045977011494);'>promising</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>of</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interfaces</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generating</span> <span style=''>visual</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>interpretations</span> <span style=''>of</span> <span style=''>semantic</span> <span style=''>content</span> <span style=''>of</span> <span style=''>a</span> <span style=''>given</span> <span style=''>natural</span> <span style=''>language</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>then</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>visualized</span> <span style=''>either</span> <span style=''>as</span> <span style=''>a</span> <span style=''>static</span> <span style=''>scene</span> <span style=''>or</span> <span style=''>a</span> <span style=''>dynamic</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>animation</span> <span style=''>This</span> <span style=''>survey</span> <span style='background-color:rgba(0, 255, 0, 0.6756756756756757);'>discusses</span> <span style='background-color:rgba(0, 255, 0, 0.4647887323943662);'>requirements</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3956043956043956);'>challenges</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developing</span> <span style=''>such</span> <span style=''>systems</span> <span style=''>and</span> <span style=''>reports</span> <span style=''>26</span> <span style='background-color:rgba(255, 0, 0, 0.3788819875776398);'>graphical</span> <span style=''>systems</span> <span style=''>that</span> <span style=''>exploit</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interfaces</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>addresses</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.39226519337016574);'>artificial</span> <span style='background-color:rgba(0, 255, 0, 0.7383177570093458);'>intelligence</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>visualization</span> <span style=''>aspects</span> <span style=''>This</span> <span style=''>work</span> <span style=''>serves</span> <span style=''>as</span> <span style=''>a</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>D2KE</span> <span style=''>From</span> <span style=''>Distance</span> <span style=''>to</span> <span style=''>Kernel</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Embedding</span> <br/><br/><span style=''>For</span> <span style=''>many</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>settings</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particularly</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>inputs</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequences</span> <span style=''>or</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>objects</span> <span style=''>a</span> <span style=''>distance</span> <span style=''>measure</span> <span style=''>between</span> <span style=''>inputs</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specified</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>naturally</span> <span style=''>than</span> <span style=''>a</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>However</span> <span style=''>most</span> <span style=''>standard</span> <span style=''>machine</span> <span style=''>models</span> <span style=''>are</span> <span style=''>designed</span> <span style=''>for</span> <span style=''>inputs</span> <span style=''>with</span> <span style=''>a</span> <span style=''>vector</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>function</span> <span style=''>fmathcalX</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rightarrow</span> <span style=''>R</span> <span style=''>based</span> <span style=''>solely</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dissimilarity</span> <span style=''>measure</span> <span style=''>dmathcalXtimesmathcalX</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rightarrow</span> <span style=''>R</span> <span style=''>between</span> <span style=''>inputs</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>family</span> <span style=''>of</span> <span style=''>emphpositive</span> <span style=''>definite</span> <span style=''>kernels</span> <span style=''>from</span> <span style=''>a</span> <span style=''>given</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dissimilarity</span> <span style=''>measure</span> <span style=''>which</span> <span style=''>subsumes</span> <span style=''>the</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>emphrepresentative</span> <span style=''>set</span> <span style=''>method</span> <span style=''>as</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>and</span> <span style=''>relates</span> <span style=''>to</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>emphdistance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>substitution</span> <span style=''>kernel</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Distributed</span> <span style=''>Weighted</span> <span style='background-color:rgba(255, 0, 0, 0.3113772455089819);'>Parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Averaging</span> <span style=''>for</span> <span style=''>SVM</span> <span style=''>Training</span> <span style=''>on</span> <span style=''>Big</span> <span style=''>Data</span> <br/><br/><span style=''>Two</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>training</span> <span style=''>of</span> <span style=''>SVMs</span> <span style=''>on</span> <span style=''>big</span> <span style=''>data</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3113772455089819);'>parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>averaging</span> <span style=''>and</span> <span style=''>ADMM</span> <span style='background-color:rgba(255, 0, 0, 0.3113772455089819);'>Parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>averaging</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>but</span> <span style=''>suffers</span> <span style=''>from</span> <span style=''>loss</span> <span style=''>of</span> <span style=''>accuracy</span> <span style=''>with</span> <span style=''>increase</span> <span style=''>in</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partitions</span> <span style=''>while</span> <span style=''>ADMM</span> <span style=''>in</span> <span style=''>the</span> <span style=''>feature</span> <span style=''>space</span> <span style=''>is</span> <span style=''>accurate</span> <span style=''>but</span> <span style=''>suffers</span> <span style=''>from</span> <span style=''>slow</span> <span style='background-color:rgba(255, 0, 0, 0.3515151515151515);'>convergence</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>report</span> <span style=''>a</span> <span style=''>hybrid</span> <span style=''>approach</span> <span style=''>called</span> <span style=''>weighted</span> <span style='background-color:rgba(255, 0, 0, 0.3113772455089819);'>parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>averaging</span> <span style=''>(WPA)</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3669064748201438);'>regularized</span> <span style=''>hinge</span> <span style=''>loss</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>weights</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>The</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>be</span> <span style=''>same</span> <span style=''>as</span> <span style=''>solving</span> <span style=''>SVM</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projected</span> <span style=''>space</span> <span style=''>We</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>an</span> <span style=''>O(frac1N)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stability</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>final</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>given</span> <span style=''>by</span> <span style=''>WPA</span> <span style=''>using</span> <span style=''>novel</span> <span style=''>proof</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Engineering</span> <span style=''>Safety</span> <span style=''>in</span> <span style=''>Machine</span> <span style=''>Learning</span> <br/><br/><span style=''>Machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasingly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influencing</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decisions</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interacting</span> <span style=''>with</span> <span style=''>us</span> <span style=''>in</span> <span style=''>all</span> <span style=''>parts</span> <span style=''>of</span> <span style=''>our</span> <span style=''>daily</span> <span style=''>lives</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Therefore</span> <span style=''>just</span> <span style=''>like</span> <span style=''>for</span> <span style=''>power</span> <span style=''>plants</span> <span style=''>highways</span> <span style=''>and</span> <span style=''>myriad</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineered</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sociotechnical</span> <span style=''>systems</span> <span style=''>we</span> <span style=''>must</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>safety</span> <span style=''>of</span> <span style=''>systems</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>involving</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>first</span> <span style=''>discuss</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definition</span> <span style=''>of</span> <span style=''>safety</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>epistemic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>and</span> <span style=''>the</span> <span style=''>harm</span> <span style=''>incurred</span> <span style=''>by</span> <span style=''>unwanted</span> <span style=''>outcomes</span> <span style=''>Then</span> <span style=''>we</span> <span style=''>examine</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>choice</span> <span style=''>of</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>appropriateness</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>average</span> <span style=''>training</span> <span style=''>cost</span> <span style=''>along</span> <span style=''>which</span> <span style=''>certain</span> <span style=''>real</span> <span style=''>world</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>may</span> <span style=''>not</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completely</span> <span style=''>amenable</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>foundational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principle</span> <span style=''>of</span> <span style=''>modern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>machine</s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12215099715099716)
# 	experimental (0.14245014245014245)
# 	processing (0.10363247863247864)
# 	segmentation (0.07193732193732194)
# 	architecture (0.08974358974358974)
# 	detection (0.11787749287749288)
# 	information (0.2539173789173789)
# 	convolutional (0.12286324786324786)
# 	different (0.2777777777777778)
# 	recognition (0.13532763532763534)
#
# Some Statistics words are:
# 	statistical (0.15210843373493976)
# 	stochastic (0.13152610441767068)
# 	estimation (0.16967871485943775)
# 	variables (0.14407630522088352)
# 	theoretical (0.15512048192771086)
# 	algorithm (0.3895582329317269)
# 	distribution (0.1827309236947791)
# 	dimensional (0.18373493975903615)
# 	inference (0.20381526104417672)
# 	regression (0.17670682730923695)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="900309a7-059b-49c6-a898-de2fbf62134c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("900309a7-059b-49c6-a898-de2fbf62134c")) {                    Plotly.newPlot(                        "900309a7-059b-49c6-a898-de2fbf62134c",                        [{"x":["experiments","outperformance","importance","selective","evaluating","therefore","capabilities","detection","evaluation","proposals","applications","introduced","condition","environmental","variations","illumination","fundamental","acknowledged","combination","demonstrate","guaranteed","effectiveness","feasibility","computational","complexity","framework","imitation","aggregation","established","hierarchical","scenarios","reference","unacceptable","sufficient","predictive","approaches","complicated","efficient","integrated","generated","demonstrated","execution","representative","controller","optimization","autonomous","performance","continuously","efficiency","desirable","implementation","structure","generally","compressed","unsupervised","reconstruction","measurements","restricted","integrate","effective","statistical","correlation","distribution","generative","approximate","inference","inferring","boltzmann","structured","generalized","predominantly","procedure","investigate","information","representations","strategies","resulting","competitor","recognition","benchmarks","classification","outperform","descriptors","incorporate","addresses","selecting","informative","polynomial","representing","phenomena","posterior","observations","locations","candidate","outperforms","guarantees","processes","phenomenon","criterion","correlated","submodularity","empirical","optimized","minimizing","approximation","uncertainty","algorithms","algorithm","unfortunately","alternative","recurrent","extraction","categories","submission","identifying","treatments","resources","initialized","predefined","challenge","embeddings","challenges","automated","experimental","processing","bidirectional","handcrafted","classifying","essential","streamlined","decomposition","manipulating","probabilistically","constraints","expressive","heuristics","geometrical","collision","configurations","languages","classical","geometric","compilation","combinatorial","functions","presented","components","independent","deterministic","interactively","underlying","parameter","intriguing","clustered","generalizes","community","theoretical","contribution","theoretic","represents","connection","relationships","interesting","probability","clustering","hellinger","logarithmically","knowledge","arbitrary","independently","similarity","drastically","significantly","otherwise","attributes","divergence","stochastic","interactive","limitation","discriminate","highlighting","statistics","empirically","construct","neuroscience","normalization","interpolate","successes","important","perceptually","parametrized","different","identical","discriminable","peripheral","dimensional","coefficients","critically","observers","physically","synthesis","generation","appealing","formulate","multiscale","likelihood","occlusion","correlations","evaluated","conditional","probabilistic","importantly","representation","graphical","principled","establish","constraint","assumptions","reductions","particular","efficiently","difficulty","introduce","essentially","hypothesis","determine","satisfaction","cryptographic","technique","assumption","learnable","intersection","presently","generalization","agnostically","halfspaces","combining","implications","segmentation","discovering","quantifying","compression","capturing","marginals","causality","belonging","expression","estimating","bipartite","modelling","traditional","transitions","recursively","co ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	omnipresent
# 	seasonality
# 	decontamination
# 	noninformative
# 	sparsification
# 	consonants
# 	obscuring
# 	underpinning
# 	interfacing
# 	ellipsoids
# 	criminology
# 	surrogates
# 	protecting
# 	asymptotics
# 	uncontaminated
# 	parametrisation
# 	resurgence
# 	confident
# 	transferability
# 	regularised
# Some words which never appear in Statistics papers:
# 	unacceptable
# 	predominantly
# 	compilation
# 	observers
# 	presently
# 	argumentation
# 	affective
# 	avoidance
# 	fatalities
# 	hazardous
# 	comprehensively
# 	bilingual
# 	unpredictable
# 	mendelzons
# 	revisions
# 	formations
# 	retinopathy
# 	discourse
# 	autonomously
# 	concatenation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.060912151821243e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7475
